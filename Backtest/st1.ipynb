# %%
import st1
import os

# %%
st1.backtest_multiple_stocks
# Out:
# <function st1.backtest_multiple_stocks(stock_files, initial_cash)>

# %%
# Directory containing the stock CSV files
directory = '/Users/suganeshr/Trading/Trading_codes/nifty_200'

# List all files in the directory and filter for CSV files
stock_files = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.csv')]
try:
    results_df = st1.backtest_multiple_stocks(stock_files, 50000)
    print(results_df)
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# The error single positional indexer is out-of-bounds for index 7102
# The error single positional indexer is out-of-bounds for index 7103
# The error single positional indexer is out-of-bounds for index 7104
# The error single positional indexer is out-of-bounds for index 7105
# The error single positional indexer is out-of-bounds for index 7106
# ...

# %%
results_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 results_df
#
# NameError: name 'results_df' is not defined
